# %% [markdown]
# # 获取 GitHub 项目进展
#
# 以下代码主要由 GPT-4 生成，演示 `GitHubClient` 模块的版本演进。
#
#
# ## 使用 GitHub REST API 获取项目信息
#
# GitHub REST API 为开发者提供了便捷获取 GitHub 项目的丰富 API。
#
# ![Github Docs](images/github_docs.png)
#
# 例如，获取项目 issues 列表，GitHub 提供了 `"List repository issues"` API。
#
#
# ## GitHub Token 配置
#
# 使用 `GitHubClient` 模块调用 GitHub REST API 需要配置 [GitHub Fine-grained personal access token](https://github.com/settings/tokens?type=beta)。
#
# - **配置文件**：正式启动 GitHubSentinel 项目，可以替换 `config.json` 中 `github_token` 值。
# - **Jupyter测试**：在使用构造函数实例化 GitHubClient 类，以参数形式传入。
#
# 下面以 https://github.com/langchain-ai/langchain 项目为例，演示 GitHubClient 使用方法

# %% [markdown]
# ## [v0.2] GitHubClient Class

# %%
import os

# %%
# src/github_client.py

import requests  # 导入requests库用于发起HTTP请求
import datetime  # 导入datetime库处理日期和时间

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub的访问令牌
        # 初始化请求头部，这里主要是为了使用GitHub的API进行身份验证
        self.headers = {'Authorization': f'token {self.token}'}

    def fetch_updates(self, repos):
        # 为给定的仓库列表获取更新，包括提交、问题和拉取请求
        updates = {}
        for repo in repos:
            # 遍历每个仓库并获取相关信息
            updates[repo] = {
                # 'commits': self.fetch_commits(repo),  # 获取提交记录
                'issues': self.fetch_issues(repo),   # 获取问题
                'pull_requests': self.fetch_pull_requests(repo)  # 获取拉取请求
            }
        return updates

    def fetch_commits(self, repo):
        # 构建获取提交记录的API URL
        url = f'https://api.github.com/repos/{repo}/commits'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 检查请求是否成功，如果出错则抛出异常
        return response.json()  # 返回解析JSON格式的数据

    def fetch_issues(self, repo):
        # 构建获取问题(issue)的API URL
        url = f'https://api.github.com/repos/{repo}/issues'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 确保响应没有HTTP错误
        return response.json()  # 返回JSON数据

    def fetch_pull_requests(self, repo):
        # 构建获取拉取请求(pull requests)的API URL
        url = f'https://api.github.com/repos/{repo}/pulls'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()
        return response.json()  # 返回JSON格式的拉取请求数据

    def export_daily_progress(self, repo):
        # 导出指定仓库的每日进度，包括问题和拉取请求
        date_str = datetime.datetime.now().strftime('%Y-%m-%d')  # 获取当前日期字符串
        issues = self.fetch_issues(repo)  # 获取当天的问题
        pull_requests = self.fetch_pull_requests(repo)  # 获取当天的拉取请求
        filename = f"{repo.replace('/', '_')}_{date_str}.md"  # 根据仓库名和日期生成文件名

        # 打开文件进行写入
        with open(filename, 'w') as f:
            f.write(f"# {repo} Daily Progress - {date_str}\n\n")  # 写入标题
            f.write("## Issues\n")
            for issue in issues:
                f.write(f"- {issue['title']} #{issue['number']}\n")  # 列出每个问题
            f.write("\n## Pull Requests\n")
            for pr in pull_requests:
                f.write(f"- {pr['title']} #{pr['number']}\n")  # 列出每个拉取请求

        print(f"Exported daily progress to {filename}")  # 打印导出信息

        return filename

# %% [markdown]
# ### 实例化 GitHubClient
#
# 从环境变量中获取 `GITHUB_TOKEN`，依次获取 Commits, Issues 和 Pull Requests。

# %%
# import os

github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### List Issues API
#
# API完整文档说明见：https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues
#
# **请求样例**：`GET /repos/{owner}/{repo}/issues`;
#
# **返回样例**：
#
# ```json
# [
#   {
#     "id": 1,
#     "node_id": "MDU6SXNzdWUx",
#     "url": "https://api.github.com/repos/octocat/Hello-World/issues/1347",
#     "repository_url": "https://api.github.com/repos/octocat/Hello-World",
#     "labels_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/labels{/name}",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/comments",
#     "events_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/events",
#     "html_url": "https://github.com/octocat/Hello-World/issues/1347",
#     "number": 1347,
#     "state": "open",
#     "title": "Found a bug",
#     "body": "I'm having a problem with this.",
#     "user": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "labels": [
#       {
#         "id": 208045946,
#         "node_id": "MDU6TGFiZWwyMDgwNDU5NDY=",
#         "url": "https://api.github.com/repos/octocat/Hello-World/labels/bug",
#         "name": "bug",
#         "description": "Something isn't working",
#         "color": "f29513",
#         "default": true
#       }
#     ],
#     "assignee": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "assignees": [
#       {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       }
#     ],
#     "milestone": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/milestones/1",
#       "html_url": "https://github.com/octocat/Hello-World/milestones/v1.0",
#       "labels_url": "https://api.github.com/repos/octocat/Hello-World/milestones/1/labels",
#       "id": 1002604,
#       "node_id": "MDk6TWlsZXN0b25lMTAwMjYwNA==",
#       "number": 1,
#       "state": "open",
#       "title": "v1.0",
#       "description": "Tracking milestone for version 1.0",
#       "creator": {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       },
#       "open_issues": 4,
#       "closed_issues": 8,
#       "created_at": "2011-04-10T20:09:31Z",
#       "updated_at": "2014-03-03T18:58:10Z",
#       "closed_at": "2013-02-12T13:22:01Z",
#       "due_on": "2012-10-09T23:39:01Z"
#     },
#     "locked": true,
#     "active_lock_reason": "too heated",
#     "comments": 0,
#     "pull_request": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/pulls/1347",
#       "html_url": "https://github.com/octocat/Hello-World/pull/1347",
#       "diff_url": "https://github.com/octocat/Hello-World/pull/1347.diff",
#       "patch_url": "https://github.com/octocat/Hello-World/pull/1347.patch"
#     },
#     "closed_at": null,
#     "created_at": "2011-04-22T13:33:48Z",
#     "updated_at": "2011-04-22T13:33:48Z",
#     "closed_by": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "author_association": "COLLABORATOR",
#     "state_reason": "completed"
#   }
# ]
# ```

# %%
repo = "langchain-ai/langchain"

# %%
issues = github_client.fetch_issues(repo)

# %% [markdown]
# ### GitHubClient fetch 方法 repo 参数格式要求
#
# 从 GitHub 获取项目进展，需要访问形如 `https://api.github.com/repos/{repo}/issues`(以issues为例）的 URL。因此，repo 必须符合 GitHub Repo 标准命名，如下所示:
#
# ```json
# [
#     "langchain-ai/langchain",
#     "DjangoPeng/openai-quickstart",
#     "ollama/ollama"
# ]
# ```
#
# **GitHubSentinel 项目订阅管理配置文件为 `subscriptions.json`。**

# %%
issues
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25798',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25798/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25798/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25798/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/25798',
#   'id': 2491077945,
#   'node_id': 'I_kwDOIPDwls6UetU5',
#   'number': 25798,
#   'title': "Self query retriever with Vector Store type <class 'langchain_qdrant.qdrant.QdrantVectorStore'> not supported.",
#   'user': {'login': 'ndhoanit1112',
#    'id': 32103386,
#    'node_id': 'MDQ6VXNlcjMyMTAzMzg2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32103386?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ndhoanit1112',
#    'html_url': 'https://github.com/ndhoanit1112',
#    'followers_url': 'https://api.github.com/users/ndhoanit1112/followers',
#    'following_url': 'https://api.github.com/users/ndhoanit1112/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ndhoanit1112/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ndhoanit1112/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ndhoanit1112/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ndhoanit1112/orgs',
#    'repos_url': 'https://api.github.com/users/ndhoanit1112/repos',
#    'events_url': 'https://api.github.com/users/ndhoanit1112/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ndhoanit1112/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6411661606,
#     'node_id': 'LA_kwDOIPDwls8AAAABfioxJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/investigate',
#     'name': 'investigate',
#     'color': '4D8397',
#     'default': False,
#     'description': ''},
#    {'id': 6473370406,
#     'node_id': 'LA_kwDOIPDwls8AAAABgdfLJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20retriever',
#     'name': 'Ɑ: retriever',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to retriever module'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-28T05:22:34Z',
#   'updated_at': '2024-08-28T05:25:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\n```python\r\nfrom langchain_openai import OpenAIEmbeddings, ChatOpenAI\r\nfrom langchain.chains.query_constructor.base import AttributeInfo\r\nfrom langchain.retrievers.self_query.base import SelfQueryRetriever\r\nfrom langchain_qdrant import QdrantVectorStore\r\n\r\nqdrant_cluster_url = os.environ.get("QDRANT_CLUSTER_URL")\r\nqdrant_api_key = os.environ.get("QDRANT_API_KEY")\r\n\r\nembeddings = OpenAIEmbeddings(model="text-embedding-3-large")\r\nvectorstore = QdrantVectorStore.from_existing_collection(\r\n    url=qdrant_cluster_url,\r\n    api_key=qdrant_api_key,\r\n    collection_name="products",\r\n    embedding=embeddings,\r\n)\r\n\r\nmetadata_field_info = [\r\n    AttributeInfo(\r\n        name="is_size_customizable",\r\n        description="Whether the product size can be customized when ordering or not, \'Yes\' or \'No\'",\r\n        type="string",\r\n    )\r\n]\r\ndocument_content_description = "Brief description and some key features of a product"\r\n\r\nllm = ChatOpenAI(temperature=0.5, model="gpt-4o")\r\nretriever = SelfQueryRetriever.from_llm(\r\n    llm, vectorstore, document_content_description, metadata_field_info, verbose=True\r\n)\r\n\r\nretriever.invoke("size customizable table")\r\n```\n\n### Error Message and Stack Trace (if applicable)\n\n```\r\nFile "/Users/ndhoanit1112/Source/xxx/test.py", line 335, in query_qdrant\r\n    retriever = SelfQueryRetriever.from_llm(\r\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/Users/ndhoanit1112/Source/xxx/.venv/lib/python3.12/site-packages/langchain/retrievers/self_query/base.py", line 314, in from_llm\r\n    structured_query_translator = _get_builtin_translator(vectorstore)\r\n                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/Users/ndhoanit1112/Source/xxx/.venv/lib/python3.12/site-packages/langchain/retrievers/self_query/base.py", line 190, in _get_builtin_translator\r\n    raise ValueError(\r\nValueError: Self query retriever with Vector Store type <class \'langchain_qdrant.qdrant.QdrantVectorStore\'> not supported.\r\n```\n\n### Description\n\nThe Self Query Retriever does support Qdrant [(doc)](https://python.langchain.com/v0.2/docs/integrations/retrievers/self_query/qdrant_self_query/). However, I found that the `Qdrant` class in the document is imported from from `langchain_community.vectorstores`, which was deprecated. So the Self Query Retriever should support the `QdrantVectorStore` class from `langchain_qdrant.qdrant`.\n\n### System Info\n\n```\r\nlangchain==0.2.14\r\nlangchain-community==0.2.12\r\nlangchain-core==0.2.35\r\nlangchain-openai==0.1.22\r\nlangchain-qdrant==0.1.3\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25798/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25798/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25797',
#   'id': 2491055456,
#   'node_id': 'PR_kwDOIPDwls55p8lv',
#   'number': 25797,
#   'title': 'Patch enable to use Amazon OpenSearch Serverless(aoss) for Semantic Cache store',
#   'user': {'login': 'jinoos',
#    'id': 1274562,
#    'node_id': 'MDQ6VXNlcjEyNzQ1NjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1274562?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jinoos',
#    'html_url': 'https://github.com/jinoos',
#    'followers_url': 'https://api.github.com/users/jinoos/followers',
#    'following_url': 'https://api.github.com/users/jinoos/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jinoos/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jinoos/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jinoos/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jinoos/orgs',
#    'repos_url': 'https://api.github.com/users/jinoos/repos',
#    'events_url': 'https://api.github.com/users/jinoos/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jinoos/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5454193895,
#     'node_id': 'LA_kwDOIPDwls8AAAABRRhk5w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/lgtm',
#     'name': 'lgtm',
#     'color': '0E8A16',
#     'default': False,
#     'description': 'PR looks good. Use to confirm that a PR is ready for merging.'},
#    {'id': 5680700883,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid0w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:nit',
#     'name': '🤖:nit',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Small modifications/deletions, fixes, deps or improvements to existing code or docs'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-08-28T05:05:10Z',
#   'updated_at': '2024-08-28T06:44:00Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25797',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25797',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25797.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25797.patch',
#    'merged_at': None},
#   'body': '- [x] **PR title**: "community: Patch enable to use Amazon OpenSearch Serverless for Semantic Cache store"\r\n\r\n- [x] **PR message**: \r\n    - **Description:**OpenSearchSemanticCache class support Amazon OpenSearch Serverless for Semantic Cache store, it\'s only required to pass auth(http_auth) parameter to initializer\r\n    - **Dependencies:** none\r\n\r\n- [x] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration: yes\r\n  2. an example notebook showing its use: yes\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25796',
#   'id': 2491041637,
#   'node_id': 'PR_kwDOIPDwls55p5ns',
#   'number': 25796,
#   'title': '[Evaluation] New Constrained COT evaluator',
#   'user': {'login': 'GMartin-dev',
#    'id': 1821407,
#    'node_id': 'MDQ6VXNlcjE4MjE0MDc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1821407?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GMartin-dev',
#    'html_url': 'https://github.com/GMartin-dev',
#    'followers_url': 'https://api.github.com/users/GMartin-dev/followers',
#    'following_url': 'https://api.github.com/users/GMartin-dev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/GMartin-dev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/GMartin-dev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/GMartin-dev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/GMartin-dev/orgs',
#    'repos_url': 'https://api.github.com/users/GMartin-dev/repos',
#    'events_url': 'https://api.github.com/users/GMartin-dev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/GMartin-dev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 6232714119,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rhw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:M',
#     'name': 'size:M',
#     'color': 'FEF2C0',
#     'default': False,
#     'description': 'This PR changes 30-99 lines, ignoring generated files.'},
#    {'id': 7110712909,
#     'node_id': 'LA_kwDOIPDwls8AAAABp9TeTQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/langchain',
#     'name': 'langchain',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Related to the langchain package'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-28T04:54:00Z',
#   'updated_at': '2024-08-28T05:28:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25796',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25796',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25796.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25796.patch',
#    'merged_at': None},
#   'body': 'This PR adds a new evaluator implemented with a new technique derived from COT.\r\nI have been using for our use cases to reduce token length generation / cost and improve test speed.\r\nBeyond the obvious upside of cost / speed reduction I think is important that Langchain exposes diverse prompting patterns by example.\r\n\r\nOriginal Paper:\r\n[[Concise Thoughts: Impact of Output Length on LLM Reasoning and Cost] ](https://arxiv.org/pdf/2407.19825)\r\n\r\n>  constraining the reasoning of LLaMA2-70b to 100 words\r\nimproves the accuracy from 36.01% (CoT) to\r\n41.07% (CCoT) on the GSM8K dataset, while\r\nreducing the average output length by 28 words\r\n\r\n<img width="502" alt="image" src="https://github.com/user-attachments/assets/9f9fed43-4982-4f30-a313-0ca77d4789de">\r\n\r\n<img width="491" alt="image" src="https://github.com/user-attachments/assets/90bfbdcb-e4a8-4b4e-ab9d-6d5149bed3e1">\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25795',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25795/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25795/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25795/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/25795',
#   'id': 2490973884,
#   'node_id': 'I_kwDOIPDwls6UeT68',
#   'number': 25795,
#   'title': 'SQL Record Manager',
#   'user': {'login': 'Hanson-G2G',
#    'id': 178129163,
#    'node_id': 'U_kgDOCp4JCw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/178129163?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hanson-G2G',
#    'html_url': 'https://github.com/Hanson-G2G',
#    'followers_url': 'https://api.github.com/users/Hanson-G2G/followers',
#    'following_url': 'https://api.github.com/users/Hanson-G2G/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Hanson-G2G/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Hanson-G2G/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Hanson-G2G/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Hanson-G2G/orgs',
#    'repos_url': 'https://api.github.com/users/Hanson-G2G/repos',
#    'events_url': 'https://api.github.com/users/Hanson-G2G/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Hanson-G2G/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6411661606,
#     'node_id': 'LA_kwDOIPDwls8AAAABfioxJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/investigate',
#     'name': 'investigate',
#     'color': '4D8397',
#     'default': False,
#     'description': ''},
#    {'id': 6713033886,
#     'node_id': 'LA_kwDOIPDwls8AAAABkCDEng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-28T04:29:35Z',
#   'updated_at': '2024-08-28T07:22:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\nThe following code: ```python```\r\nimport os\r\nfrom utils import vec_db\r\nfrom dotenv import load_dotenv\r\nfrom langchain.indexes import SQLRecordManager, index\r\nfrom langchain.text_splitter import RecursiveCharacterTextSplitter\r\nfrom langchain_aws.vectorstores.inmemorydb import InMemoryVectorStore\r\n\r\nload_dotenv()\r\ncollection_name = "vectordb"\r\nnamespace = f"memoryDB/{collection_name}"\r\nSQL_RECORD_MANAGER_DB_URL = os.environ.get(\'SQL_RECORD_MANAGER_DB_URL\')\r\nMEMORYDB_CLUSTER_URL=os.environ.get(\'MEMORYDB_CLUSTER_URL\')\r\nPOSTGRES_DB_URL=os.environ.get(\'POSTGRES_DB_URL\')\r\nembeddings_model = vec_db.choose_embeddings_model(vec_db.VOYAGE_MODEL)\r\n\r\ndef train_agent(links):\r\n    record_manager = SQLRecordManager(namespace, db_url="mysql+pymysql://3JUWd9LLVLo9omY.root:yVo9wqYCvoEy0gxz@gateway01.ap-southeast-1.prod.aws.tidbcloud.com:4000/vectordb?ssl_ca=/etc/ssl/cert.pem&ssl_verify_cert=true&ssl_verify_identity=true")\r\n    vector_store = InMemoryVectorStore(\r\n        embedding=embeddings_model,\r\n        index_name=collection_name,\r\n        redis_url="redis://clustercfg.memorydb-test.gltu4g.memorydb.us-west-2.amazonaws.com:6379",\r\n    )\r\n    record_manager.create_schema()\r\n    docs = RecursiveCharacterTextSplitter(separators=["\\n\\n", "\\n", ".", " ", "\\u200b", "\\uff0c", "\\u3001","\\uff0e", "\\u3002"], chunk_size=1000, chunk_overlap=200).split_documents(get_docs(links=links))\r\n    indexing = index(docs, record_manager, vector_store, cleanup="full")\r\n    return indexing\r\n\r\ndef get_docs(links=None):\r\n    """\r\n    Load documents from files in specified directories or from provided web links.\r\n\r\n    Args:\r\n        links (list or str, optional): A list of URLs or a single URL to load content from.\r\n    \r\n    Returns:\r\n        list: A list of Document objects ready for embedding.\r\n    """\r\n    docs = []\r\n    directory=False\r\n    # Load documents from directories\r\n    if directory:\r\n        for directory in directories:\r\n            files = get_all_files(directory)\r\n            for file_path in files:\r\n                ext = os.path.splitext(file_path)[-1]\r\n                if ext in {\'.mhtml\', \'.csv\', \'.html\', \'.json\', \'.jsonl\', \'.pdf\'}:\r\n                    loader = {\r\n                        \'.mhtml\': MHTMLLoader,\r\n                        \'.csv\': CSVLoader,\r\n                        \'.html\': UnstructuredHTMLLoader,\r\n                        \'.json\': JSONLoader,\r\n                        \'.jsonl\': JSONLoader,\r\n                        \'.pdf\': PyPDFLoader,\r\n                    }[ext](file_path)\r\n                    docs.extend(loader.load())\r\n                else:\r\n                    with open(file_path, \'r\', encoding=\'utf-8\') as file:\r\n                        data = file.read()\r\n                        doc = Document(page_content=data, metadata={"source": file_path})\r\n                        docs.append(doc)\r\n    \r\n    # Load documents from provided web links\r\n    if links:\r\n        if isinstance(links, str):\r\n            links = [links]\r\n        for link in links:\r\n            loader = SitemapLoader(web_path=link) if link.endswith(".xml") else FireCrawlLoader(link, mode="crawl")\r\n            docs.extend(loader.load())\r\n    \r\n    return docs\n\n### Error Message and Stack Trace (if applicable)\n\nTraceback (most recent call last):\r\n  File "/Users/hansonloo/miniconda3/envs/website-agent/lib/python3.10/site-packages/sql ...
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25795/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25795/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25793',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25793/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25793/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25793/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25793',
#   'id': 2490862533,
#   'node_id': 'PR_kwDOIPDwls55peJt',
#   'number': 25793,
#   'title': 'bug发现和修复',
#   'user': {'login': 'dongfangduoshou123',
#    'id': 22514720,
#    'node_id': 'MDQ6VXNlcjIyNTE0NzIw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22514720?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dongfangduoshou123',
#    'html_url': 'https://github.com/dongfangduoshou123',
#    'followers_url': 'https://api.github.com/users/dongfangduoshou123/followers',
#    'following_url': 'https://api.github.com/users/dongfangduoshou123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dongfangduoshou123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dongfangduoshou123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dongfangduoshou123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dongfangduoshou123/orgs',
#    'repos_url': 'https://api.github.com/users/dongfangduoshou123/repos',
#    'events_url': 'https://api.github.com/users/dongfangduoshou123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dongfangduoshou123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 5796266916,
#     'node_id': 'LA_kwDOIPDwls8AAAABWXwDpA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%94%8C:%20milvus',
#     'name': '🔌: milvus',
#     'color': 'BFD4F2',
#     'default': False,
#     'description': 'Primarily related to Milvus vector store integration'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 6348691034,
#     'node_id': 'LA_kwDOIPDwls8AAAABemlWWg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/partner',
#     'name': 'partner',
#     'color': 'ededed',
#     'default': False,
#     'description': None},
#    {'id': 7110712909,
#     'node_id': 'LA_kwDOIPDwls8AAAABp9TeTQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/langchain',
#     'name': 'langchain',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Related to the langchain package'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-28T03:22:11Z',
#   'updated_at': '2024-08-28T04:12:18Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25793',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25793',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25793.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25793.patch',
#    'merged_at': None},
#   'body': 'collection.search方法的data字段接收的参数应为List[float]类型，\r\n如果传List[List[float]]，那么会导致pymilvus库报错：<milvusexception: (code=1, message=unexpected error, message=<required argument is not a float>)>\r\n\r\nThank you for contributing to LangChain!\r\n\r\n- [ ] **PR title**: "package: description"\r\n  - Where "package" is whichever of langchain, community, core, experimental, etc. is being modified. Use "docs: ..." for purely docs changes, "templates: ..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\n- [ ] **PR message**: ***Delete this entire checklist*** and replace with\r\n    - **Description:** a description of the change\r\n    - **Issue:** the issue # it fixes, if applicable\r\n    - **Dependencies:** any dependencies required for this change\r\n    - **Twitter handle:** if your PR gets announced, and you\'d like a mention, we\'ll gladly shout you out!\r\n\r\n\r\n- [ ] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration, preferably unit tests that do not rely on network access,\r\n  2. an example notebook showing its use. It lives in `docs/docs/integrations` directory.\r\n\r\n\r\n- [ ] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you\'ve modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25793/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25793/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25791',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25791/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25791/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25791/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/25791',
#   'id': 2490843851,
#   'node_id': 'I_kwDOIPDwls6Ud0LL',
#   'number': 25791,
#   'title': 'zep_could memory error： TypeError: ZepCloudMemory() takes no arguments',
#   'user': {'login': 'Tensionteng',
#    'id': 86091294,
#    'node_id': 'MDQ6VXNlcjg2MDkxMjk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86091294?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Tensionteng',
#    'html_url': 'https://github.com/Tensionteng',
#    'followers_url': 'https://api.github.com/users/Tensionteng/followers',
#    'following_url': 'https://api.github.com/users/Tensionteng/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Tensionteng/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Tensionteng/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Tensionteng/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Tensionteng/orgs',
#    'repos_url': 'https://api.github.com/users/Tensionteng/repos',
#    'events_url': 'https://api.github.com/users/Tensionteng/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Tensionteng/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-08-28T03:01:01Z',
#   'updated_at': '2024-08-28T03:03:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\r\n\r\n- [X] I added a very descriptive title to this issue.\r\n- [X] I searched the LangChain documentation with the integrated search.\r\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\r\n- [X] I am sure that this is a bug in LangChain rather than my code.\r\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\r\n\r\n### Example Code\r\n```\r\nfrom langchain_community.memory.zep_cloud_memory import ZepCloudMemory\r\n\r\n# Set up Zep Chat History\r\nmemory = ZepCloudMemory(\r\n    session_id=session_id,\r\n    api_key=zep_api_key,\r\n    return_messages=True,\r\n    memory_key="chat_history",\r\n)\r\n```\r\n### Error Message and Stack Trace (if applicable)\r\n```\r\nTypeError: ZepCloudMemory() takes no arguments\r\n```\r\n### Description\r\n\r\nI follow the [doc](https://python.langchain.ac.cn/v0.2/docs/integrations/memory/zep_memory_cloud/#example) and write the code\r\n```\r\nfrom langchain_community.memory.zep_cloud_memory import ZepCloudMemory\r\n\r\n# Set up Zep Chat History\r\nmemory = ZepCloudMemory(\r\n    session_id=session_id,\r\n    api_key=zep_api_key,\r\n    return_messages=True,\r\n    memory_key="chat_history",\r\n)\r\n```\r\nthen it raise a error:\r\n```\r\nTypeError: ZepCloudMemory() takes no arguments\r\n```\r\nso I click into the class [ZepCloudMemory](https://github.com/langchain-ai/langchain/blob/master/libs/community/langchain_community/memory/zep_cloud_memory.py#L9), the source code as below:\r\n```\r\ntry:\r\n    from langchain.memory import ConversationBufferMemory\r\n    from zep_cloud import MemoryGetRequestMemoryType\r\n\r\n    class ZepCloudMemory(ConversationBufferMemory):\r\n        # something\r\n\r\nexcept ImportError:\r\n    # Placeholder object\r\n    class ZepCloudMemory:  # type: ignore[no-redef]\r\n        pass\r\n```\r\nthe code `from zep_cloud import MemoryGetRequestMemoryType`  has a import error.\r\nthe code will jump into `except` block and retuen a class with no constructor.\r\n\r\n### System Info\r\n\r\npython==3.10\r\nlangchain-community==0.2.5\r\nlangchain-core==0.2.33\r\nzep-cloud==1.0.9',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25791/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25791/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25787',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25787/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25787/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25787/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25787',
#   'id': 2490560926,
#   'node_id': 'PR_kwDOIPDwls55op60',
#   'number': 25787,
#   'title': 'core: prompt variable error msg',
#   'user': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5454193895,
#     'node_id': 'LA_kwDOIPDwls8AAAABRRhk5w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/lgtm',
#     'name': 'lgtm',
#     'color': '0E8A16',
#     'default': False,
#     'description': 'PR looks good. Use to confirm that a PR is ready for merging.'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 6713033886,
#     'node_id': 'LA_kwDOIPDwls8AAAABkCDEng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-27T23:58:29Z',
#   'updated_at': '2024-08-27T23:59:47Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25787',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25787',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25787.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25787.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25787/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25787/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25781',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25781/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25781/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25781/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25781',
#   'id': 2489687672,
#   'node_id': 'PR_kwDOIPDwls55l11-',
#   'number': 25781,
#   'title': 'community: add score to PineconeHybridSearchRetriever',
#   'user': {'login': 'cjber',
#    'id': 44099524,
#    'node_id': 'MDQ6VXNlcjQ0MDk5NTI0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44099524?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cjber',
#    'html_url': 'https://github.com/cjber',
#    'followers_url': 'https://api.github.com/users/cjber/followers',
#    'following_url': 'https://api.github.com/users/cjber/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cjber/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cjber/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cjber/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cjber/orgs',
#    'repos_url': 'https://api.github.com/users/cjber/repos',
#    'events_url': 'https://api.github.com/users/cjber/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cjber/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 6473370406,
#     'node_id': 'LA_kwDOIPDwls8AAAABgdfLJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20retriever',
#     'name': 'Ɑ: retriever',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to retriever module'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-27T15:17:07Z',
#   'updated_at': '2024-08-27T15:19:30Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25781',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25781',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25781.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25781.patch',
#    'merged_at': None},
#   'body': "**Description:**\r\n\r\nAdds the 'score' returned by Pinecone to the `PineconeHybridSearchRetriever` list of returned Documents.\n\nThere is currently no way to return the score when using Pinecone hybrid search, so in this PR I include it by default.",
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25781/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25781/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25779',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25779/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25779/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25779/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25779',
#   'id': 2489672124,
#   'node_id': 'PR_kwDOIPDwls55lyYE',
#   'number': 25779,
#   'title': 'Feature/update hunyuan',
#   'user': {'login': 'xander-art',
#    'id': 178459432,
#    'node_id': 'U_kgDOCqMTKA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/178459432?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xander-art',
#    'html_url': 'https://github.com/xander-art',
#    'followers_url': 'https://api.github.com/users/xander-art/followers',
#    'following_url': 'https://api.github.com/users/xander-art/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/xander-art/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/xander-art/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/xander-art/subscriptions',
#    'organizations_url': 'https://api.github.com/users/xander-art/orgs',
#    'repos_url': 'https://api.github.com/users/xander-art/repos',
#    'events_url': 'https://api.github.com/users/xander-art/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xander-art/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 6232714119,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rhw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:M',
#     'name': 'size:M',
#     'color': 'FEF2C0',
#     'default': False,
#     'description': 'This PR changes 30-99 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'ccurme',
#     'id': 26529506,
#     'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ccurme',
#     'html_url': 'https://github.com/ccurme',
#     'followers_url': 'https://api.github.com/users/ccurme/followers',
#     'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#     'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#     'repos_url': 'https://api.github.com/users/ccurme/repos',
#     'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-27T15:11:24Z',
#   'updated_at': '2024-08-28T03:13:07Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25779',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25779',
# ...
#    'starred_url': 'https://api.github.com/users/codekiln/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/codekiln/subscriptions',
#    'organizations_url': 'https://api.github.com/users/codekiln/orgs',
#    'repos_url': 'https://api.github.com/users/codekiln/repos',
#    'events_url': 'https://api.github.com/users/codekiln/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/codekiln/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 6411661606,
#     'node_id': 'LA_kwDOIPDwls8AAAABfioxJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/investigate',
#     'name': 'investigate',
#     'color': '4D8397',
#     'default': False,
#     'description': ''},
#    {'id': 6713033886,
#     'node_id': 'LA_kwDOIPDwls8AAAABkCDEng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'baskaryan',
#     'id': 22008038,
#     'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/baskaryan',
#     'html_url': 'https://github.com/baskaryan',
#     'followers_url': 'https://api.github.com/users/baskaryan/followers',
#     'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#     'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#     'repos_url': 'https://api.github.com/users/baskaryan/repos',
#     'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-08-25T10:13:41Z',
#   'updated_at': '2024-08-26T15:10:50Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\r\n\r\n- [X] I added a very descriptive title to this issue.\r\n- [X] I searched the LangChain documentation with the integrated search.\r\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\r\n- [X] I am sure that this is a bug in LangChain rather than my code.\r\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\r\n\r\n### Example Code\r\n\r\nThe following is a python module with two passing pytest entries. The first proves the expected behavior, and the second shows a deviation from expected behavior.  \r\n\r\n1.  The first test `test_azure_openai_default_configured_with_bedrock_passing` demonstrates using `init_chat_model()` to set a default chat LLM and then later configuring it to use a different chat LLM. This test passes, which demonstrates this functionality works at a basic level.\r\n2. The second test `test_azure_openai_default_with_temperature_configured_with_bedrock_failing` is the same test, but it introduces `temperature` in the default chat LLM model parameters, and then attempts to instantiate a different model (in this case, AzureChatOpenAI), which raises `pydantic.v1.ValidationError` (which, in this case, is trapped by `with pytest.raises(ValidationError)`. This test is coded to pass because it expects this error.  \r\n\r\n\r\n```python\r\nimport os\r\n\r\nimport pytest\r\nfrom dotenv import load_dotenv\r\nfrom langchain.chat_models import init_chat_model\r\nfrom langsmith import traceable\r\nfrom pydantic.v1 import ValidationError\r\n\r\nload_dotenv()\r\n\r\nAZURE_OPENAI_GPT_35_TURBO_DEPLOYMENT_NAME = os.getenv(\r\n    "AZURE_OPENAI_GPT_35_TURBO_DEPLOYMENT_NAME"\r\n)\r\n\r\nBEDROCK_CLAUDE_3_HAIKU_MODEL_ID = os.getenv(\r\n    "BEDROCK_CLAUDE_3_HAIKU_MODEL_ID", "anthropic.claude-3-haiku-20240307-v1:0"\r\n)\r\n\r\nPROMPT = "What\'s your name?"\r\n\r\n\r\n"""\r\nThis module demonstrates an incompatibility between the usage of init_chat_model() with AzureOpenAI and Bedrock models\r\nwhen the default model uses extra parameters that are not allowed in the Bedrock model.\r\n"""\r\n\r\n\r\n@traceable()\r\ndef test_azure_openai_default_configured_with_bedrock_passing():\r\n    """\r\n    This passing test demonstrates that we can set a default of an AzureOpenAI model and then\r\n    configure it with a Bedrock model.\r\n    """\r\n\r\n    configurable_chat_model = init_chat_model(\r\n        AZURE_OPENAI_GPT_35_TURBO_DEPLOYMENT_NAME,\r\n        model_provider="azure_openai",\r\n        configurable_fields="any",\r\n    )\r\n\r\n    azure_result = configurable_chat_model.invoke(PROMPT)\r\n    assert azure_result.response_metadata["model_name"] == "gpt-35-turbo"\r\n\r\n    bedrock_result = configurable_chat_model.with_config(\r\n        configurable={\r\n            "model": BEDROCK_CLAUDE_3_HAIKU_MODEL_ID,\r\n            "model_provider": "bedrock",\r\n        }\r\n    ).invoke(PROMPT)\r\n    assert (\r\n        bedrock_result.response_metadata["model_id"] == BEDROCK_CLAUDE_3_HAIKU_MODEL_ID\r\n    )\r\n\r\n\r\n@traceable()\r\ndef test_azure_openai_default_with_temperature_configured_with_bedrock_failing():\r\n    """\r\n    This is the same as the test above, but it fails because temperature is not allowed in the Bedrock model,\r\n    hence the pytest.raises(ValidationError), which comes from pydantic.\r\n    """\r\n    configurable_chat_model = init_chat_model(\r\n        AZURE_OPENAI_GPT_35_TURBO_DEPLOYMENT_NAME,\r\n        model_provider="azure_openai",\r\n        configurable_fields="any",\r\n        temperature=0.2,\r\n    )\r\n\r\n    azure_result = configurable_chat_model.invoke(PROMPT)\r\n    assert azure_result.response_metadata["model_name"] == "gpt-35-turbo"\r\n\r\n    with pytest.raises(ValidationError) as ve:\r\n        bedrock_result = configurable_chat_model.with_config(\r\n            configurable={\r\n                "model": BEDROCK_CLAUDE_3_HAIKU_MODEL_ID,\r\n  ...
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25731/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25731/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25728',
#   'id': 2484914653,
#   'node_id': 'PR_kwDOIPDwls55VuGE',
#   'number': 25728,
#   'title': 'community: Minor Improvement of extract hyperlinks tool output',
#   'user': {'login': 'zysoong',
#    'id': 75294755,
#    'node_id': 'MDQ6VXNlcjc1Mjk0NzU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75294755?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zysoong',
#    'html_url': 'https://github.com/zysoong',
#    'followers_url': 'https://api.github.com/users/zysoong/followers',
#    'following_url': 'https://api.github.com/users/zysoong/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zysoong/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zysoong/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zysoong/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zysoong/orgs',
#    'repos_url': 'https://api.github.com/users/zysoong/repos',
#    'events_url': 'https://api.github.com/users/zysoong/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zysoong/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700883,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid0w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:nit',
#     'name': '🤖:nit',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Small modifications/deletions, fixes, deps or improvements to existing code or docs'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-24T23:04:44Z',
#   'updated_at': '2024-08-25T10:33:28Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25728',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25728',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25728.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25728.patch',
#    'merged_at': None},
#   'body': "**Description:** Make the hyperlink only appear once in the extract_hyperlinks tool output. (for some websites output contains meaningless '#' hyperlinks multiple times which will extend the tokens of context window without any advantage)\r\n**Issue:** None\r\n**Dependencies:** None\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25727',
#   'id': 2484863143,
#   'node_id': 'PR_kwDOIPDwls55VjjN',
#   'number': 25727,
#   'title': 'community: fix model initialization bug for deepinfra',
#   'user': {'login': 'mo374z',
#    'id': 87517800,
#    'node_id': 'MDQ6VXNlcjg3NTE3ODAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87517800?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mo374z',
#    'html_url': 'https://github.com/mo374z',
#    'followers_url': 'https://api.github.com/users/mo374z/followers',
#    'following_url': 'https://api.github.com/users/mo374z/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mo374z/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mo374z/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mo374z/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mo374z/orgs',
#    'repos_url': 'https://api.github.com/users/mo374z/repos',
#    'events_url': 'https://api.github.com/users/mo374z/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mo374z/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-24T21:01:08Z',
#   'updated_at': '2024-08-24T21:11:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25727',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25727',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25727.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25727.patch',
#    'merged_at': None},
#   'body': '### Description\r\nadds an init method to ChatDeepInfra to set the model_name attribute accordings to the argument\r\n### Issue\r\ncurrently, the model_name specified by the user during initialization of the ChatDeepInfra class is never set. Therefore, it always chooses the default model (meta-llama/Llama-2-70b-chat-hf, however probably since this is deprecated it always uses meta-llama/Llama-3-70b-Instruct). We stumbled across this issue and fixed it as proposed in this pull request. Feel free to change the fix according to your coding guidelines and style, this is just a proposal and we want to draw attention to this problem.\r\n### Dependencies\r\nno additional dependencies required\r\n\r\nFeel free to contact me or @timo282 and @finitearth if you have any questions.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# ### List Pull Requests API
#
# API完整文档说明见：https://docs.github.com/en/rest/pulls/pulls?apiVersion=2022-11-28#list-pull-requests
#
# **请求样例**：`GET /repos/{owner}/{repo}/pulls`;

# %%
pull_requests = github_client.fetch_pull_requests(repo)

# %%
pull_requests
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25797',
#   'id': 2041039215,
#   'node_id': 'PR_kwDOIPDwls55p8lv',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25797',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/25797.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/25797.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797',
#   'number': 25797,
#   'state': 'open',
#   'locked': False,
#   'title': 'Patch enable to use Amazon OpenSearch Serverless(aoss) for Semantic Cache store',
#   'user': {'login': 'jinoos',
#    'id': 1274562,
#    'node_id': 'MDQ6VXNlcjEyNzQ1NjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1274562?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jinoos',
#    'html_url': 'https://github.com/jinoos',
#    'followers_url': 'https://api.github.com/users/jinoos/followers',
#    'following_url': 'https://api.github.com/users/jinoos/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jinoos/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jinoos/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jinoos/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jinoos/orgs',
#    'repos_url': 'https://api.github.com/users/jinoos/repos',
#    'events_url': 'https://api.github.com/users/jinoos/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jinoos/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': '- [x] **PR title**: "community: Patch enable to use Amazon OpenSearch Serverless for Semantic Cache store"\r\n\r\n- [x] **PR message**: \r\n    - **Description:**OpenSearchSemanticCache class support Amazon OpenSearch Serverless for Semantic Cache store, it\'s only required to pass auth(http_auth) parameter to initializer\r\n    - **Dependencies:** none\r\n\r\n- [x] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration: yes\r\n  2. an example notebook showing its use: yes\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.',
#   'created_at': '2024-08-28T05:05:10Z',
#   'updated_at': '2024-08-28T06:44:00Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '590d675a60a6919132ac707115f218e2987dfd82',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5454193895,
#     'node_id': 'LA_kwDOIPDwls8AAAABRRhk5w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/lgtm',
#     'name': 'lgtm',
#     'color': '0E8A16',
#     'default': False,
#     'description': 'PR looks good. Use to confirm that a PR is ready for merging.'},
#    {'id': 5680700883,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid0w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:nit',
#     'name': '🤖:nit',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Small modifications/deletions, fixes, deps or improvements to existing code or docs'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25797/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25797/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/b18f98278e74f2e6a9912c41fea5b09eb3c0998d',
#   'head': {'label': 'jinoos:support-aws-opensearch-serverless',
#    'ref': 'support-aws-opensearch-serverless',
#    'sha': 'b18f98278e74f2e6a9912c41fea5b09eb3c0998d',
#    'user': {'login': 'jinoos',
#     'id': 1274562,
#     'node_id': 'MDQ6VXNlcjEyNzQ1NjI=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/1274562?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jinoos',
#     'html_url': 'https://github.com/jinoos',
#     'followers_url': 'https://api.github.com/users/jinoos/followers',
#     'following_url': 'https://api.github.com/users/jinoos/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jinoos/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jinoos/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jinoos/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jinoos/orgs',
#     'repos_url': 'https://api.github.com/users/jinoos/repos',
#     'events_url': 'https://api.github.com/users/jinoos/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jinoos/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 848140588,
#     'node_id': 'R_kgDOMo2ZLA',
#     'name': 'langchain',
#     'full_name': 'jinoos/langchain',
#     'private': False,
#     'owner': {'login': 'jinoos',
#      'id': 1274562,
#      'node_id': 'MDQ6VXNlcjEyNzQ1NjI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1274562?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jinoos',
#      'html_url': 'https://github.com/jinoos',
#      'followers_url': 'https://api.github.com/users/jinoos/followers',
#      'following_url': 'https://api.github.com/users/jinoos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jinoos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jinoos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jinoos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jinoos/orgs',
#      'repos_url': 'https://api.github.com/users/jinoos/repos',
#      'events_url': 'https://api.github.com/users/jinoos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jinoos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/jinoos/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/jinoos/langchain',
#     'forks_url': 'https://api.github.com/repos/jinoos/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/jinoos/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/jinoos/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/jinoos/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/jinoos/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/jinoos/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/jinoos/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/jinoos/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/jinoos/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/jinoos/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/jinoos/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/jinoos/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/jinoos/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/jinoos/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/jinoos/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/jinoos/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/jinoos/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/jinoos/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/jinoos/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/jinoos/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/jinoos/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/jinoos/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/jinoos/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/jinoos/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/jinoos/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/jinoos/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/jinoos/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/jinoos/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/jinoos/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/jinoos/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/jinoos/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/jinoos/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/jinoos/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/jinoos/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/jinoos/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/jinoos/langchain/deployments',
#     'created_at': '2024-08-27T07:54:07Z',
#     'updated_at': '2024-08-27T07:54:08Z',
#     'pushed_at': '2024-08-28T04:27:49Z',
#     'git_url': 'git://github.com/jinoos/langchain.git',
#     'ssh_url': 'git@github.com:jinoos/langchain.git',
#     'clone_url': 'https://github.com/jinoos/langchain.git',
#     'svn_url': 'https://github.com/jinoos/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 236020,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': 'd5ddaac1fcc48349e4b17290d7ddc78a95b6d7a1',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-28T07:40:51Z',
#     'pushed_at': '2024-08-28T07:09:29Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 289510,
#     'stargazers_count': 91327,
#     'watchers_count': 91327,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14526,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 888,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14526,
#     'open_issues': 888,
#     'watchers': 91327,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25797'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25797'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25797/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25797/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25797/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/b18f98278e74f2e6a9912c41fea5b09eb3c0998d'}},
#   'author_association': 'NONE',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25796',
#   'id': 2041027052,
#   'node_id': 'PR_kwDOIPDwls55p5ns',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25796',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/25796.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/25796.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796',
#   'number': 25796,
#   'state': 'open',
#   'locked': False,
#   'title': '[Evaluation] New Constrained COT evaluator',
#   'user': {'login': 'GMartin-dev',
#    'id': 1821407,
#    'node_id': 'MDQ6VXNlcjE4MjE0MDc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1821407?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GMartin-dev',
#    'html_url': 'https://github.com/GMartin-dev',
#    'followers_url': 'https://api.github.com/users/GMartin-dev/followers',
#    'following_url': 'https://api.github.com/users/GMartin-dev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/GMartin-dev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/GMartin-dev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/GMartin-dev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/GMartin-dev/orgs',
#    'repos_url': 'https://api.github.com/users/GMartin-dev/repos',
#    'events_url': 'https://api.github.com/users/GMartin-dev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/GMartin-dev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': 'This PR adds a new evaluator implemented with a new technique derived from COT.\r\nI have been using for our use cases to reduce token length generation / cost and improve test speed.\r\nBeyond the obvious upside of cost / speed reduction I think is important that Langchain exposes diverse prompting patterns by example.\r\n\r\nOriginal Paper:\r\n[[Concise Thoughts: Impact of Output Length on LLM Reasoning and Cost] ](https://arxiv.org/pdf/2407.19825)\r\n\r\n>  constraining the reasoning of LLaMA2-70b to 100 words\r\nimproves the accuracy from 36.01% (CoT) to\r\n41.07% (CCoT) on the GSM8K dataset, while\r\nreducing the average output length by 28 words\r\n\r\n<img width="502" alt="image" src="https://github.com/user-attachments/assets/9f9fed43-4982-4f30-a313-0ca77d4789de">\r\n\r\n<img width="491" alt="image" src="https://github.com/user-attachments/assets/90bfbdcb-e4a8-4b4e-ab9d-6d5149bed3e1">\r\n\r\n',
#   'created_at': '2024-08-28T04:54:00Z',
#   'updated_at': '2024-08-28T05:28:34Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '3c3b77deaf79ace2ee6bcd207d19b0752a4d29a6',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 6232714119,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rhw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:M',
#     'name': 'size:M',
#     'color': 'FEF2C0',
#     'default': False,
#     'description': 'This PR changes 30-99 lines, ignoring generated files.'},
#    {'id': 7110712909,
#     'node_id': 'LA_kwDOIPDwls8AAAABp9TeTQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/langchain',
#     'name': 'langchain',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Related to the langchain package'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25796/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25796/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/6eecff837a2113961d3c10210bd7c2d48b143c65',
#   'head': {'label': 'GMartin-dev:constrained-cot-evaluator',
#    'ref': 'constrained-cot-evaluator',
#    'sha': '6eecff837a2113961d3c10210bd7c2d48b143c65',
#    'user': {'login': 'GMartin-dev',
#     'id': 1821407,
#     'node_id': 'MDQ6VXNlcjE4MjE0MDc=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/1821407?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/GMartin-dev',
#     'html_url': 'https://github.com/GMartin-dev',
#     'followers_url': 'https://api.github.com/users/GMartin-dev/followers',
#     'following_url': 'https://api.github.com/users/GMartin-dev/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/GMartin-dev/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/GMartin-dev/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/GMartin-dev/subscriptions',
#     'organizations_url': 'https://api.github.com/users/GMartin-dev/orgs',
#     'repos_url': 'https://api.github.com/users/GMartin-dev/repos',
#     'events_url': 'https://api.github.com/users/GMartin-dev/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/GMartin-dev/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 641225854,
#     'node_id': 'R_kgDOJjhUfg',
#     'name': 'langchain',
#     'full_name': 'GMartin-dev/langchain',
#     'private': False,
#     'owner': {'login': 'GMartin-dev',
#      'id': 1821407,
#      'node_id': 'MDQ6VXNlcjE4MjE0MDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1821407?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/GMartin-dev',
#      'html_url': 'https://github.com/GMartin-dev',
#      'followers_url': 'https://api.github.com/users/GMartin-dev/followers',
#      'following_url': 'https://api.github.com/users/GMartin-dev/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/GMartin-dev/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/GMartin-dev/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/GMartin-dev/subscriptions',
#      'organizations_url': 'https://api.github.com/users/GMartin-dev/orgs',
#      'repos_url': 'https://api.github.com/users/GMartin-dev/repos',
#      'events_url': 'https://api.github.com/users/GMartin-dev/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/GMartin-dev/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/GMartin-dev/langchain',
#     'description': '⚡ Building applications with LLMs through composability ⚡',
#     'fork': True,
#     'url': 'https://api.github.com/repos/GMartin-dev/langchain',
#     'forks_url': 'https://api.github.com/repos/GMartin-dev/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/GMartin-dev/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/GMartin-dev/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/GMartin-dev/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/GMartin-dev/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/GMartin-dev/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/GMartin-dev/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/GMartin-dev/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/GMartin-dev/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/GMartin-dev/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/GMartin-dev/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/GMartin-dev/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/GMartin-dev/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/GMartin-dev/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/GMartin-dev/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/GMartin-dev/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/GMartin-dev/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/GMartin-dev/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/GMartin-dev/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/GMartin-dev/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/GMartin-dev/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/GMartin-dev/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/GMartin-dev/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/GMartin-dev/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/GMartin-dev/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/GMartin-dev/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/GMartin-dev/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/GMartin-dev/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/GMartin-dev/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/GMartin-dev/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/GMartin-dev/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/GMartin-dev/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/GMartin-dev/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/GMartin-dev/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/GMartin-dev/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/GMartin-dev/langchain/deployments',
#     'created_at': '2023-05-16T03:25:51Z',
#     'updated_at': '2024-08-28T05:06:00Z',
#     'pushed_at': '2024-08-28T05:28:17Z',
#     'git_url': 'git://github.com/GMartin-dev/langchain.git',
#     'ssh_url': 'git@github.com:GMartin-dev/langchain.git',
#     'clone_url': 'https://github.com/GMartin-dev/langchain.git',
#     'svn_url': 'https://github.com/GMartin-dev/langchain',
#     'homepage': '',
#     'size': 236108,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': 'd5ddaac1fcc48349e4b17290d7ddc78a95b6d7a1',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-28T07:40:51Z',
#     'pushed_at': '2024-08-28T07:09:29Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 289510,
#     'stargazers_count': 91327,
#     'watchers_count': 91327,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14526,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 888,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14526,
#     'open_issues': 888,
#     'watchers': 91327,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25796'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25796'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25796/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25796/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25796/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/6eecff837a2113961d3c10210bd7c2d48b143c65'}},
#   'author_association': 'CONTRIBUTOR',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25793',
#   'id': 2040914541,
#   'node_id': 'PR_kwDOIPDwls55peJt',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25793',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/25793.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/25793.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25793',
#   'number': 25793,
#   'state': 'open',
#   'locked': False,
#   'title': 'bug发现和修复',
#   'user': {'login': 'dongfangduoshou123',
#    'id': 22514720,
#    'node_id': 'MDQ6VXNlcjIyNTE0NzIw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22514720?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dongfangduoshou123',
#    'html_url': 'https://github.com/dongfangduoshou123',
#    'followers_url': 'https://api.github.com/users/dongfangduoshou123/followers',
#    'following_url': 'https://api.github.com/users/dongfangduoshou123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dongfangduoshou123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dongfangduoshou123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dongfangduoshou123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dongfangduoshou123/orgs',
#    'repos_url': 'https://api.github.com/users/dongfangduoshou123/repos',
#    'events_url': 'https://api.github.com/users/dongfangduoshou123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dongfangduoshou123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': 'collection.search方法的data字段接收的参数应为List[float]类型，\r\n如果传List[List[float]]，那么会导致pymilvus库报错：<milvusexception: (code=1, message=unexpected error, message=<required argument is not a float>)>\r\n\r\nThank you for contributing to LangChain!\r\n\r\n- [ ] **PR title**: "package: description"\r\n  - Where "package" is whichever of langchain, community, core, experimental, etc. is being modified. Use "docs: ..." for purely docs changes, "templates: ..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\n- [ ] **PR message**: ***Delete this entire checklist*** and replace with\r\n    - **Description:** a description of the change\r\n    - **Issue:** the issue # it fixes, if applicable\r\n    - **Dependencies:** any dependencies required for this change\r\n    - **Twitter handle:** if your PR gets announced, and you\'d like a mention, we\'ll gladly shout you out!\r\n\r\n\r\n- [ ] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration, preferably unit tests that do not rely on network access,\r\n  2. an example notebook showing its use. It lives in `docs/docs/integrations` directory.\r\n\r\n\r\n- [ ] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you\'ve modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n',
#   'created_at': '2024-08-28T03:22:11Z',
#   'updated_at': '2024-08-28T04:12:18Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': 'f6d6c0fe085d527abacacaddeb3d03b56c5ff987',
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 5796266916,
#     'node_id': 'LA_kwDOIPDwls8AAAABWXwDpA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%94%8C:%20milvus',
#     'name': '🔌: milvus',
#     'color': 'BFD4F2',
#     'default': False,
#     'description': 'Primarily related to Milvus vector store integration'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 6348691034,
#     'node_id': 'LA_kwDOIPDwls8AAAABemlWWg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/partner',
#     'name': 'partner',
#     'color': 'ededed',
#     'default': False,
#     'description': None},
#    {'id': 7110712909,
#     'node_id': 'LA_kwDOIPDwls8AAAABp9TeTQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/langchain',
#     'name': 'langchain',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Related to the langchain package'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25793/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25793/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25793/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/20077e47d05b56c3105858d321230a45cc3867df',
#   'head': {'label': 'dongfangduoshou123:patch-1',
#    'ref': 'patch-1',
#    'sha': '20077e47d05b56c3105858d321230a45cc3867df',
#    'user': {'login': 'dongfangduoshou123',
#     'id': 22514720,
#     'node_id': 'MDQ6VXNlcjIyNTE0NzIw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/22514720?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/dongfangduoshou123',
#     'html_url': 'https://github.com/dongfangduoshou123',
#     'followers_url': 'https://api.github.com/users/dongfangduoshou123/followers',
#     'following_url': 'https://api.github.com/users/dongfangduoshou123/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/dongfangduoshou123/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/dongfangduoshou123/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/dongfangduoshou123/subscriptions',
#     'organizations_url': 'https://api.github.com/users/dongfangduoshou123/orgs',
#     'repos_url': 'https://api.github.com/users/dongfangduoshou123/repos',
#     'events_url': 'https://api.github.com/users/dongfangduoshou123/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/dongfangduoshou123/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 769040368,
#     'node_id': 'R_kgDOLdaf8A',
#     'name': 'langchain',
#     'full_name': 'dongfangduoshou123/langchain',
#     'private': False,
#     'owner': {'login': 'dongfangduoshou123',
#      'id': 22514720,
#      'node_id': 'MDQ6VXNlcjIyNTE0NzIw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/22514720?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dongfangduoshou123',
#      'html_url': 'https://github.com/dongfangduoshou123',
# ...
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25645/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25645/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/46b46315a5f18b2c79268e0601c6b8746cfd0ae3',
#   'head': {'label': 'langchain-ai:bagatur/structured_prompt_kwargs',
#    'ref': 'bagatur/structured_prompt_kwargs',
#    'sha': '46b46315a5f18b2c79268e0601c6b8746cfd0ae3',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-28T07:40:51Z',
#     'pushed_at': '2024-08-28T07:09:29Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 289510,
#     'stargazers_count': 91327,
#     'watchers_count': 91327,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14526,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 888,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14526,
#     'open_issues': 888,
#     'watchers': 91327,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': 'fb1d67edf6f667d7f32820b16d63de93512b2c6d',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-28T07:40:51Z',
#     'pushed_at': '2024-08-28T07:09:29Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 289510,
#     'stargazers_count': 91327,
#     'watchers_count': 91327,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14526,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 888,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14526,
#     'open_issues': 888,
#     'watchers': 91327,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25645'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25645'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25645/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25645/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/46b46315a5f18b2c79268e0601c6b8746cfd0ae3'}},
#   'author_association': 'COLLABORATOR',
#   'auto_merge': None,
#   'active_lock_reason': None}]

# %% [markdown]
# ### List Commits API
#
# API完整文档说明见：https://docs.github.com/en/rest/commits/commits?apiVersion=2022-11-28
#
# **请求样例**：`GET /repos/{owner}/{repo}/commits`;

# %%
commits = github_client.fetch_commits(repo)

# %%
commits
# Out:
# [{'sha': 'bda3becbe77a22ce49d77c59035727f3b2ed64f1',
#   'node_id': 'C_kwDOIPDwltoAKGJkYTNiZWNiZTc3YTIyY2U0OWQ3N2M1OTAzNTcyN2YzYjJlZDY0ZjE',
#   'commit': {'author': {'name': 'gbaian10',
#     'email': '34255899+gbaian10@users.noreply.github.com',
#     'date': '2024-08-18T06:23:24Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-18T06:23:24Z'},
#    'message': 'docs: add prompt to install beautifulsoup4. (#25518)\n\nfix: #25482\r\n\r\n- **Description:**\r\nAdd a prompt to install beautifulsoup4 in places where `from\r\nlangchain_community.document_loaders import WebBaseLoader` is used.\r\n- **Issue:** #25482',
#    'tree': {'sha': '9a455072059fea04bbb3a900c019a4ab09b075ad',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/9a455072059fea04bbb3a900c019a4ab09b075ad'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/bda3becbe77a22ce49d77c59035727f3b2ed64f1',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nej3SvW0sGdIom7paYSiS\n=nh7J\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 9a455072059fea04bbb3a900c019a4ab09b075ad\nparent f6e6a1787815195e849bf9e133980d8cbafa52f2\nauthor gbaian10 <34255899+gbaian10@users.noreply.github.com> 1723962204 +0800\ncommitter GitHub <noreply@github.com> 1723962204 -0700\n\ndocs: add prompt to install beautifulsoup4. (#25518)\n\nfix: #25482\r\n\r\n- **Description:**\r\nAdd a prompt to install beautifulsoup4 in places where `from\r\nlangchain_community.document_loaders import WebBaseLoader` is used.\r\n- **Issue:** #25482'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/bda3becbe77a22ce49d77c59035727f3b2ed64f1',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/bda3becbe77a22ce49d77c59035727f3b2ed64f1',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/bda3becbe77a22ce49d77c59035727f3b2ed64f1/comments',
#   'author': {'login': 'gbaian10',
#    'id': 34255899,
#    'node_id': 'MDQ6VXNlcjM0MjU1ODk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34255899?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gbaian10',
#    'html_url': 'https://github.com/gbaian10',
#    'followers_url': 'https://api.github.com/users/gbaian10/followers',
#    'following_url': 'https://api.github.com/users/gbaian10/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gbaian10/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gbaian10/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gbaian10/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gbaian10/orgs',
#    'repos_url': 'https://api.github.com/users/gbaian10/repos',
#    'events_url': 'https://api.github.com/users/gbaian10/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gbaian10/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'f6e6a1787815195e849bf9e133980d8cbafa52f2',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f6e6a1787815195e849bf9e133980d8cbafa52f2',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/f6e6a1787815195e849bf9e133980d8cbafa52f2'}]},
#  {'sha': 'f6e6a1787815195e849bf9e133980d8cbafa52f2',
#   'node_id': 'C_kwDOIPDwltoAKGY2ZTZhMTc4NzgxNTE5NWU4NDliZjllMTMzOTgwZDhjYmFmYTUyZjI',
#   'commit': {'author': {'name': 'gbaian10',
#     'email': '34255899+gbaian10@users.noreply.github.com',
#     'date': '2024-08-18T06:22:49Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-18T06:22:49Z'},
#    'message': 'docs: add prompt to install nltk (#25519)\n\nfix: #25473 \r\n\r\n- **Description:** add prompt to install nltk\r\n- **Issue:** #25473',
#    'tree': {'sha': 'f1e3b532c6571c96fcd6e0cade9506a28944d050',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/f1e3b532c6571c96fcd6e0cade9506a28944d050'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/f6e6a1787815195e849bf9e133980d8cbafa52f2',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\njWaPL71uK42Znck6uH91\n=aoDU\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree f1e3b532c6571c96fcd6e0cade9506a28944d050\nparent c1bd4e05bcd180a36ba7b5d89ca2b5ce4f1e5d4a\nauthor gbaian10 <34255899+gbaian10@users.noreply.github.com> 1723962169 +0800\ncommitter GitHub <noreply@github.com> 1723962169 -0700\n\ndocs: add prompt to install nltk (#25519)\n\nfix: #25473 \r\n\r\n- **Description:** add prompt to install nltk\r\n- **Issue:** #25473'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f6e6a1787815195e849bf9e133980d8cbafa52f2',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/f6e6a1787815195e849bf9e133980d8cbafa52f2',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f6e6a1787815195e849bf9e133980d8cbafa52f2/comments',
#   'author': {'login': 'gbaian10',
#    'id': 34255899,
#    'node_id': 'MDQ6VXNlcjM0MjU1ODk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34255899?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gbaian10',
#    'html_url': 'https://github.com/gbaian10',
#    'followers_url': 'https://api.github.com/users/gbaian10/followers',
#    'following_url': 'https://api.github.com/users/gbaian10/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gbaian10/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gbaian10/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gbaian10/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gbaian10/orgs',
#    'repos_url': 'https://api.github.com/users/gbaian10/repos',
#    'events_url': 'https://api.github.com/users/gbaian10/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gbaian10/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'c1bd4e05bcd180a36ba7b5d89ca2b5ce4f1e5d4a',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c1bd4e05bcd180a36ba7b5d89ca2b5ce4f1e5d4a',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/c1bd4e05bcd180a36ba7b5d89ca2b5ce4f1e5d4a'}]},
#  {'sha': 'c1bd4e05bcd180a36ba7b5d89ca2b5ce4f1e5d4a',
#   'node_id': 'C_kwDOIPDwltoAKGMxYmQ0ZTA1YmNkMTgwYTM2YmE3YjVkODljYTJiNWNlNGYxZTVkNGE',
#   'commit': {'author': {'name': 'Chengzu Ou',
#     'email': 'chengzu.ou@databricks.com',
#     'date': '2024-08-16T20:24:30Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-16T20:24:30Z'},
#    'message': 'docs: fix Databricks Vector Search demo notebook (#25504)\n\n**Description:** This PR fixes an issue in the demo notebook of\r\nDatabricks Vector Search in "Work with Delta Sync Index" section.\r\n\r\n**Issue:** N/A\r\n\r\n**Dependencies:** N/A\r\n\r\n---------\r\n\r\nCo-authored-by: Chengzu Ou <chengzu.ou@databrick.com>\r\nCo-authored-by: Erick Friis <erick@langchain.dev>',
#    'tree': {'sha': 'eba445bc77134a22a9fca29d8413d00ff1a9e96e',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/eba445bc77134a22a9fca29d8413d00ff1a9e96e'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/c1bd4e05bcd180a36ba7b5d89ca2b5ce4f1e5d4a',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nJOGn+kMq+inObWbrYfqF\n=K2RU\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree eba445bc77134a22a9fca29d8413d00ff1a9e96e\nparent a2e90a5a43bb2b70bed99fd280c054cc1cb999de\nauthor Chengzu Ou <chengzu.ou@databricks.com> 1723839870 -0700\ncommitter GitHub <noreply@github.com> 1723839870 +0000\n\ndocs: fix Databricks Vector Search demo notebook (#25504)\n\n**Description:** This PR fixes an issue in the demo notebook of\r\nDatabricks Vector Search in "Work with Delta Sync Index" section.\r\n\r\n**Issue:** N/A\r\n\r\n**Dependencies:** N/A\r\n\r\n---------\r\n\r\nCo-authored-by: Chengzu Ou <chengzu.ou@databrick.com>\r\nCo-authored-by: Erick Friis <erick@langchain.dev>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c1bd4e05bcd180a36ba7b5d89ca2b5ce4f1e5d4a',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/c1bd4e05bcd180a36ba7b5d89ca2b5ce4f1e5d4a',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c1bd4e05bcd180a36ba7b5d89ca2b5ce4f1e5d4a/comments',
#   'author': {'login': 'freemso',
#    'id': 10937540,
#    'node_id': 'MDQ6VXNlcjEwOTM3NTQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10937540?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/freemso',
#    'html_url': 'https://github.com/freemso',
#    'followers_url': 'https://api.github.com/users/freemso/followers',
#    'following_url': 'https://api.github.com/users/freemso/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/freemso/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/freemso/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/freemso/subscriptions',
#    'organizations_url': 'https://api.github.com/users/freemso/orgs',
#    'repos_url': 'https://api.github.com/users/freemso/repos',
#    'events_url': 'https://api.github.com/users/freemso/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/freemso/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'a2e90a5a43bb2b70bed99fd280c054cc1cb999de',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/a2e90a5a43bb2b70bed99fd280c054cc1cb999de',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/a2e90a5a43bb2b70bed99fd280c054cc1cb999de'}]},
#  {'sha': 'a2e90a5a43bb2b70bed99fd280c054cc1cb999de',
#   'node_id': 'C_kwDOIPDwltoAKGEyZTkwYTVhNDNiYjJiNzBiZWQ5OWZkMjgwYzA1NGNjMWNiOTk5ZGU',
#   'commit': {'author': {'name': 'Isaac Francisco',
#     'email': '78627776+isahers1@users.noreply.github.com',
#     'date': '2024-08-16T20:20:37Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-16T20:20:37Z'},
#    'message': 'add embeddings integration tests (#25508)',
#    'tree': {'sha': 'fe6f43687b0d17b4d480e0fb04644181a08d4608',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/fe6f43687b0d17b4d480e0fb04644181a08d4608'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/a2e90a5a43bb2b70bed99fd280c054cc1cb999de',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nP880Vw+2Nl2QEeNZxCoK\n=06kk\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree fe6f43687b0d17b4d480e0fb04644181a08d4608\nparent a06818a6543793e1b21f5896135244949e02c8e1\nauthor Isaac Francisco <78627776+isahers1@users.noreply.github.com> 1723839637 -0700\ncommitter GitHub <noreply@github.com> 1723839637 -0700\n\nadd embeddings integration tests (#25508)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/a2e90a5a43bb2b70bed99fd280c054cc1cb999de',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/a2e90a5a43bb2b70bed99fd280c054cc1cb999de',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/a2e90a5a43bb2b70bed99fd280c054cc1cb999de/comments',
#   'author': {'login': 'isahers1',
#    'id': 78627776,
#    'node_id': 'MDQ6VXNlcjc4NjI3Nzc2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78627776?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/isahers1',
#    'html_url': 'https://github.com/isahers1',
#    'followers_url': 'https://api.github.com/users/isahers1/followers',
#    'following_url': 'https://api.github.com/users/isahers1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/isahers1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/isahers1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/isahers1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/isahers1/orgs',
#    'repos_url': 'https://api.github.com/users/isahers1/repos',
#    'events_url': 'https://api.github.com/users/isahers1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/isahers1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'a06818a6543793e1b21f5896135244949e02c8e1',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/a06818a6543793e1b21f5896135244949e02c8e1',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/a06818a6543793e1b21f5896135244949e02c8e1'}]},
#  {'sha': 'a06818a6543793e1b21f5896135244949e02c8e1',
#   'node_id': 'C_kwDOIPDwltoAKGEwNjgxOGE2NTQzNzkzZTFiMjFmNTg5NjEzNTI0NDk0OWUwMmM4ZTE',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-08-16T18:30:17Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-16T18:30:17Z'},
#    'message': 'openai[patch]: update core dep (#25502)',
#    'tree': {'sha': '652ded0a01688cacafd92a1981716f40fa167d81',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/652ded0a01688cacafd92a1981716f40fa167d81'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/a06818a6543793e1b21f5896135244949e02c8e1',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nmi+kqSDfnSx3fanvw0fT\n=K/ef\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 652ded0a01688cacafd92a1981716f40fa167d81\nparent df98552b6f1e3f81c153703b9a47c0d7e62890d6\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1723833017 -0700\ncommitter GitHub <noreply@github.com> 1723833017 +0000\n\nopenai[patch]: update core dep (#25502)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/a06818a6543793e1b21f5896135244949e02c8e1',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/a06818a6543793e1b21f5896135244949e02c8e1',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/a06818a6543793e1b21f5896135244949e02c8e1/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'df98552b6f1e3f81c153703b9a47c0d7e62890d6',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/df98552b6f1e3f81c153703b9a47c0d7e62890d6',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/df98552b6f1e3f81c153703b9a47c0d7e62890d6'}]},
#  {'sha': 'df98552b6f1e3f81c153703b9a47c0d7e62890d6',
#   'node_id': 'C_kwDOIPDwltoAKGRmOTg1NTJiNmYxZTNmODFjMTUzNzAzYjlhNDdjMGQ3ZTYyODkwZDY',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-08-16T18:18:54Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-16T18:18:54Z'},
#    'message': 'core[patch]: Release 0.2.33 (#25498)',
#    'tree': {'sha': 'dd2f01c8f66fb71e22e1c71132e1c7dbc19983d1',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/dd2f01c8f66fb71e22e1c71132e1c7dbc19983d1'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/df98552b6f1e3f81c153703b9a47c0d7e62890d6',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nGvhfr1c2Y2sfV8/XDjIu\n=b0+H\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree dd2f01c8f66fb71e22e1c71132e1c7dbc19983d1\nparent b83f1eb0d56dbf99605a1fce93953ee09d77aabf\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1723832334 -0700\ncommitter GitHub <noreply@github.com> 1723832334 -0700\n\ncore[patch]: Release 0.2.33 (#25498)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/df98552b6f1e3f81c153703b9a47c0d7e62890d6',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/df98552b6f1e3f81c153703b9a47c0d7e62890d6',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/df98552b6f1e3f81c153703b9a47c0d7e62890d6/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'b83f1eb0d56dbf99605a1fce93953ee09d77aabf',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b83f1eb0d56dbf99605a1fce93953ee09d77aabf',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/b83f1eb0d56dbf99605a1fce93953ee09d77aabf'}]},
#  {'sha': 'b83f1eb0d56dbf99605a1fce93953ee09d77aabf',
#   'node_id': 'C_kwDOIPDwltoAKGI4M2YxZWIwZDU2ZGJmOTk2MDVhMWZjZTkzOTUzZWUwOWQ3N2FhYmY',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2024-08-16T17:18:09Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-16T17:18:09Z'},
#    'message': 'core, partners: implement standard tracing params for LLMs (#25410)',
#    'tree': {'sha': 'a9db38a4921ca0ccde84b0f2c50a8e61d3dd1c86',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/a9db38a4921ca0ccde84b0f2c50a8e61d3dd1c86'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/b83f1eb0d56dbf99605a1fce93953ee09d77aabf',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nZSg8wG0OTTyGd4+5a6q9\n=22mk\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree a9db38a4921ca0ccde84b0f2c50a8e61d3dd1c86\nparent 9f0c76bf89e0837254516fe2a57281f827a89beb\nauthor ccurme <chester.curme@gmail.com> 1723828689 -0400\ncommitter GitHub <noreply@github.com> 1723828689 -0400\n\ncore, partners: implement standard tracing params for LLMs (#25410)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b83f1eb0d56dbf99605a1fce93953ee09d77aabf',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/b83f1eb0d56dbf99605a1fce93953ee09d77aabf',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b83f1eb0d56dbf99605a1fce93953ee09d77aabf/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '9f0c76bf89e0837254516fe2a57281f827a89beb',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/9f0c76bf89e0837254516fe2a57281f827a89beb',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/9f0c76bf89e0837254516fe2a57281f827a89beb'}]},
#  {'sha': '9f0c76bf89e0837254516fe2a57281f827a89beb',
#   'node_id': 'C_kwDOIPDwltoAKDlmMGM3NmJmODllMDgzNzI1NDUxNmZlMmE1NzI4MWY4MjdhODliZWI',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-08-16T16:53:04Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-16T16:53:04Z'},
#    'message': 'openai[patch]: Release 0.1.22 (#25496)',
#    'tree': {'sha': '0c187386135b28a8c174d9da0e9c1fdee847ccf2',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/0c187386135b28a8c174d9da0e9c1fdee847ccf2'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/9f0c76bf89e0837254516fe2a57281f827a89beb',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nt6ku/Mnil+7Uy9RpPVhW\n=jZeb\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 0c187386135b28a8c174d9da0e9c1fdee847ccf2\nparent 01ecd0acba22f8bf84c56a603c3e277ce5bc7ae6\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1723827184 -0700\ncommitter GitHub <noreply@github.com> 1723827184 +0000\n\nopenai[patch]: Release 0.1.22 (#25496)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/9f0c76bf89e0837254516fe2a57281f827a89beb',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/9f0c76bf89e0837254516fe2a57281f827a89beb',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/9f0c76bf89e0837254516fe2a57281f827a89beb/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '01ecd0acba22f8bf84c56a603c3e277ce5bc7ae6',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/01ecd0acba22f8bf84c56a603c3e277ce5bc7ae6',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/01ecd0acba22f8bf84c56a603c3e277ce5bc7ae6'}]},
#  {'sha': '01ecd0acba22f8bf84c56a603c3e277ce5bc7ae6',
#   'node_id': 'C_kwDOIPDwltoAKDAxZWNkMGFjYmEyMmY4YmY4NGM1NmE2MDNjM2UyNzdjZTViYzdhZTY',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2024-08-16T16:50:50Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-16T16:50:50Z'},
#    'message': 'openai[patch]: fix json mode for Azure (#25488)\n\nhttps://github.com/langchain-ai/langchain/issues/25479\r\nhttps://github.com/langchain-ai/langchain/issues/25485\r\n\r\n---------\r\n\r\nCo-authored-by: Bagatur <baskaryan@gmail.com>',
#    'tree': {'sha': 'cfb3a5069574b4efd3723c44c4eee1ed76caaa7c',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/cfb3a5069574b4efd3723c44c4eee1ed76caaa7c'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/01ecd0acba22f8bf84c56a603c3e277ce5bc7ae6',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nE7u/UDV9MW5/p7PnK1YA\n=XRbT\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree cfb3a5069574b4efd3723c44c4eee1ed76caaa7c\nparent 1fd1c1dca5bc0434422f23664cad99c8d385b198\nauthor ccurme <chester.curme@gmail.com> 1723827050 -0400\ncommitter GitHub <noreply@github.com> 1723827050 -0700\n\nopenai[patch]: fix json mode for Azure (#25488)\n\nhttps://github.com/langchain-ai/langchain/issues/25479\r\nhttps://github.com/langchain-ai/langchain/issues/25485\r\n\r\n---------\r\n\r\nCo-authored-by: Bagatur <baskaryan@gmail.com>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/01ecd0acba22f8bf84c56a603c3e277ce5bc7ae6',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/01ecd0acba22f8bf84c56a603c3e277ce5bc7ae6',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/01ecd0acba22f8bf84c56a603c3e277ce5bc7ae6/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '1fd1c1dca5bc0434422f23664cad99c8d385b198',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/1fd1c1dca5bc0434422f23664cad99c8d385b198',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/1fd1c1dca5bc0434422f23664cad99c8d385b198'}]},
#  {'sha': '1fd1c1dca5bc0434422f23664cad99c8d385b198',
#   'node_id': 'C_kwDOIPDwltoAKDFmZDFjMWRjYTViYzA0MzQ0MjJmMjM2NjRjYWQ5OWM4ZDM4NWIxOTg',
#   'commit': {'author': {'name': 'Eugene Yurtsev',
#     'email': 'eyurtsev@gmail.com',
#     'date': '2024-08-16T15:59:18Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-16T15:59:18Z'},
#    'message': 'docs: use .invoke rather than __call__ in openai integration notebook (#25494)\n\nDocumentation should be using .invoke()',
#    'tree': {'sha': '5e15b63f8d935f4db3954eb089b9f1f99cdcad84',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/5e15b63f8d935f4db3954eb089b9f1f99cdcad84'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/1fd1c1dca5bc0434422f23664cad99c8d385b198',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n7cPPSBdOvW5PfPY226Xi\n=INMS\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 5e15b63f8d935f4db3954eb089b9f1f99cdcad84\nparent 253ceca76a027a9c70b51f3ccf5ad5bfad4cf672\nauthor Eugene Yurtsev <eyurtsev@gmail.com> 1723823958 -0400\ncommitter GitHub <noreply@github.com> 1723823958 +0000\n\ndocs: use .invoke rather than __call__ in openai integration notebook (#25494)\n\nDocumentation should be using .invoke()'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/1fd1c1dca5bc0434422f23664cad99c8d385b198',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/1fd1c1dca5bc0434422f23664cad99c8d385b198',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/1fd1c1dca5bc0434422f23664cad99c8d385b198/comments',
#   'author': {'login': 'eyurtsev',
#    'id': 3205522,
#    'node_id': 'MDQ6VXNlcjMyMDU1MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3205522?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eyurtsev',
#    'html_url': 'https://github.com/eyurtsev',
#    'followers_url': 'https://api.github.com/users/eyurtsev/followers',
#    'following_url': 'https://api.github.com/users/eyurtsev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eyurtsev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eyurtsev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eyurtsev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eyurtsev/orgs',
#    'repos_url': 'https://api.github.com/users/eyurtsev/repos',
#    'events_url': 'https://api.github.com/users/eyurtsev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eyurtsev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '253ceca76a027a9c70b51f3ccf5ad5bfad4cf672',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/253ceca76a027a9c70b51f3ccf5ad5bfad4cf672',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/253ceca76a027a9c70b51f3ccf5ad5bfad4cf672'}]},
#  {'sha': '253ceca76a027a9c70b51f3ccf5ad5bfad4cf672',
# ...
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-15T15:26:24Z'},
#    'message': 'mistralai[patch]: Update root validator for compatibility with pydantic 2 (#25403)',
#    'tree': {'sha': '86a8345a9ec34f1827ff6295e29b7aac98ab46f1',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/86a8345a9ec34f1827ff6295e29b7aac98ab46f1'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/6f68c8d6ab2af23849f92d307df3e9ffd2ca4e0f',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\njctpFar9NHiLUrq3R0r8\n=kWmx\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 86a8345a9ec34f1827ff6295e29b7aac98ab46f1\nparent 8afbab4cf6adc5342556dd8c64db4feef1bdd5a6\nauthor Eugene Yurtsev <eyurtsev@gmail.com> 1723735584 -0400\ncommitter GitHub <noreply@github.com> 1723735584 -0400\n\nmistralai[patch]: Update root validator for compatibility with pydantic 2 (#25403)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/6f68c8d6ab2af23849f92d307df3e9ffd2ca4e0f',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/6f68c8d6ab2af23849f92d307df3e9ffd2ca4e0f',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/6f68c8d6ab2af23849f92d307df3e9ffd2ca4e0f/comments',
#   'author': {'login': 'eyurtsev',
#    'id': 3205522,
#    'node_id': 'MDQ6VXNlcjMyMDU1MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3205522?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eyurtsev',
#    'html_url': 'https://github.com/eyurtsev',
#    'followers_url': 'https://api.github.com/users/eyurtsev/followers',
#    'following_url': 'https://api.github.com/users/eyurtsev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eyurtsev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eyurtsev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eyurtsev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eyurtsev/orgs',
#    'repos_url': 'https://api.github.com/users/eyurtsev/repos',
#    'events_url': 'https://api.github.com/users/eyurtsev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eyurtsev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '8afbab4cf6adc5342556dd8c64db4feef1bdd5a6',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8afbab4cf6adc5342556dd8c64db4feef1bdd5a6',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/8afbab4cf6adc5342556dd8c64db4feef1bdd5a6'}]},
#  {'sha': '8afbab4cf6adc5342556dd8c64db4feef1bdd5a6',
#   'node_id': 'C_kwDOIPDwltoAKDhhZmJhYjRjZjZhZGM1MzQyNTU2ZGQ4YzY0ZGI0ZmVlZjFiZGQ1YTY',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2024-08-15T14:49:26Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-15T14:49:26Z'},
#    'message': 'langchain[patch]: deprecate various chains (#25310)\n\n- [x] NatbotChain: move to community, deprecate langchain version.\r\nUpdate to use `prompt | llm | output_parser` instead of LLMChain.\r\n- [x] LLMMathChain: deprecate + add langgraph replacement example to API\r\nref\r\n- [x] HypotheticalDocumentEmbedder (retriever): update to use `prompt |\r\nllm | output_parser` instead of LLMChain\r\n- [x] FlareChain: update to use `prompt | llm | output_parser` instead\r\nof LLMChain\r\n- [x] ConstitutionalChain: deprecate + add langgraph replacement example\r\nto API ref\r\n- [x] LLMChainExtractor (document compressor): update to use `prompt |\r\nllm | output_parser` instead of LLMChain\r\n- [x] LLMChainFilter (document compressor): update to use `prompt | llm\r\n| output_parser` instead of LLMChain\r\n- [x] RePhraseQueryRetriever (retriever): update to use `prompt | llm |\r\noutput_parser` instead of LLMChain',
#    'tree': {'sha': '4c9dd2f02e02693fc2dd959e147fa0f49fd8b9b4',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/4c9dd2f02e02693fc2dd959e147fa0f49fd8b9b4'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/8afbab4cf6adc5342556dd8c64db4feef1bdd5a6',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nultanMLQ4kOoJGIsgL+S\n=q1Rw\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 4c9dd2f02e02693fc2dd959e147fa0f49fd8b9b4\nparent 66e30efa61f94d2ea4ea23276c03ca1585d8b817\nauthor ccurme <chester.curme@gmail.com> 1723733366 -0400\ncommitter GitHub <noreply@github.com> 1723733366 -0400\n\nlangchain[patch]: deprecate various chains (#25310)\n\n- [x] NatbotChain: move to community, deprecate langchain version.\r\nUpdate to use `prompt | llm | output_parser` instead of LLMChain.\r\n- [x] LLMMathChain: deprecate + add langgraph replacement example to API\r\nref\r\n- [x] HypotheticalDocumentEmbedder (retriever): update to use `prompt |\r\nllm | output_parser` instead of LLMChain\r\n- [x] FlareChain: update to use `prompt | llm | output_parser` instead\r\nof LLMChain\r\n- [x] ConstitutionalChain: deprecate + add langgraph replacement example\r\nto API ref\r\n- [x] LLMChainExtractor (document compressor): update to use `prompt |\r\nllm | output_parser` instead of LLMChain\r\n- [x] LLMChainFilter (document compressor): update to use `prompt | llm\r\n| output_parser` instead of LLMChain\r\n- [x] RePhraseQueryRetriever (retriever): update to use `prompt | llm |\r\noutput_parser` instead of LLMChain'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8afbab4cf6adc5342556dd8c64db4feef1bdd5a6',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/8afbab4cf6adc5342556dd8c64db4feef1bdd5a6',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8afbab4cf6adc5342556dd8c64db4feef1bdd5a6/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '66e30efa61f94d2ea4ea23276c03ca1585d8b817',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/66e30efa61f94d2ea4ea23276c03ca1585d8b817',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/66e30efa61f94d2ea4ea23276c03ca1585d8b817'}]},
#  {'sha': '66e30efa61f94d2ea4ea23276c03ca1585d8b817',
#   'node_id': 'C_kwDOIPDwltoAKDY2ZTMwZWZhNjFmOTRkMmVhNGVhMjMyNzZjMDNjYTE1ODVkOGI4MTc',
#   'commit': {'author': {'name': 'Luke',
#     'email': '58807644+munday-tech@users.noreply.github.com',
#     'date': '2024-08-15T14:46:30Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-15T14:46:30Z'},
#    'message': 'experimental: Fix divide by 0 error (#25439)\n\nWithin the semantic chunker, when calling `_threshold_from_clusters`\r\nthere is the possibility for a divide by 0 error if the\r\n`number_of_chunks` is equal to the length of `distances`.\r\n\r\nFix simply implements a check if these values match to prevent the error\r\nand enable chunking to continue.',
#    'tree': {'sha': 'e606996cbd87383bbd0cb93a12afea0f2fcb092f',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/e606996cbd87383bbd0cb93a12afea0f2fcb092f'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/66e30efa61f94d2ea4ea23276c03ca1585d8b817',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n1RVpQ5yF9yeLjuJyVebW\n=Ki/k\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree e606996cbd87383bbd0cb93a12afea0f2fcb092f\nparent ba167dc15852043f185c12103fde00f28b14a29c\nauthor Luke <58807644+munday-tech@users.noreply.github.com> 1723733190 +1000\ncommitter GitHub <noreply@github.com> 1723733190 +0000\n\nexperimental: Fix divide by 0 error (#25439)\n\nWithin the semantic chunker, when calling `_threshold_from_clusters`\r\nthere is the possibility for a divide by 0 error if the\r\n`number_of_chunks` is equal to the length of `distances`.\r\n\r\nFix simply implements a check if these values match to prevent the error\r\nand enable chunking to continue.'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/66e30efa61f94d2ea4ea23276c03ca1585d8b817',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/66e30efa61f94d2ea4ea23276c03ca1585d8b817',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/66e30efa61f94d2ea4ea23276c03ca1585d8b817/comments',
#   'author': {'login': 'munday-tech',
#    'id': 58807644,
#    'node_id': 'MDQ6VXNlcjU4ODA3NjQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58807644?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/munday-tech',
#    'html_url': 'https://github.com/munday-tech',
#    'followers_url': 'https://api.github.com/users/munday-tech/followers',
#    'following_url': 'https://api.github.com/users/munday-tech/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/munday-tech/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/munday-tech/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/munday-tech/subscriptions',
#    'organizations_url': 'https://api.github.com/users/munday-tech/orgs',
#    'repos_url': 'https://api.github.com/users/munday-tech/repos',
#    'events_url': 'https://api.github.com/users/munday-tech/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/munday-tech/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'ba167dc15852043f185c12103fde00f28b14a29c',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ba167dc15852043f185c12103fde00f28b14a29c',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/ba167dc15852043f185c12103fde00f28b14a29c'}]}]

# %% [markdown]
# ## 解析导出每日进展
#
# API 请求返回结构过于复杂，我们先解析 `title` 字段，即仅查看和总结 GitHub 项目 Issues list 和 PRs List 标题。如下所示：
#
# ![Issues](images/issues.png)
#
# https://github.com/langchain-ai/langchain/issues

# %%
github_client.export_daily_progress(repo)
# Out:
# Exported daily progress to langchain-ai_langchain_2024-08-28.md
# 'langchain-ai_langchain_2024-08-28.md'

# %% [markdown]
# ### 查看文档 发现问题并不简单😈😈
#
# #### Note: Every pull request is an issue
#
# > GitHub's REST API considers every pull request an issue, but not every issue is a pull request. For this reason, "Issues" endpoints may return both issues and pull requests in the response. You can identify pull requests by the pull_request key. Be aware that the id of a pull request returned from "Issues" endpoints will be an issue id. To find out the pull request id, use the "List pull requests" endpoint.

# %% [markdown]
# # 支持条件筛选的 GitHub 项目进展获取
#
# 实际开发场景中，项目进展通常不是刚好以天为周期时。因此，这便暴露出v0.2版本的 `GitHubClient` 在信息获取方面的局限性。
#
#
# 下面我们扩展 v0.2 版本的 `GitHubClient`，使其支持根据筛选条件获取 GitHub 项目的 Issues 和 Pull Requests。首要支持的筛选条便是**研发周期（时间段）**，**已合并的PR** 和 **已关闭的Issues**：
#
# ![langchain_week_progress](images/langchain_week_progress.jpg)
#
# 通过阅读 GitHub API 文档（https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues--code-samples ），我们便能了解最关键的2个字段是：
#
# - state(string): Indicates the state of the issues to return.
#     - Default: open
#     - Can be one of: open, closed, all
# - since(string): Only show results that were last updated after the given time. This is a timestamp in ISO 8601 format: YYYY-MM-DDTHH:MM:SSZ.
#
# 从功能完整性角度，我们还可以增加一个 `until` 条件，以支持研发周期的结束时间筛选。😈😈
#
#
# 下面以 Langchain 项目 (https://github.com/langchain-ai/langchain) 为例，展示如何使用扩展后的 GitHubClient
#
# ## [v0.3] GitHubClient Class

# %%
# src/logger.py
from loguru import logger
import sys

# Configure Loguru
logger.remove()  # Remove the default logger
logger.add(sys.stdout, level="DEBUG", format="{time} {level} {message}", colorize=True)
logger.add("logs/app.log", rotation="1 MB", level="DEBUG")

# Alias the logger for easier import
LOG = logger

# Make the logger available for import with the alias
__all__ = ["LOG"]


# src/github_client.py

import requests  # 导入requests库用于HTTP请求
from datetime import datetime, date, timedelta  # 导入日期处理模块
import os  # 导入os模块用于文件和目录操作
# from logger import LOG  # 导入日志模块（演示时直接导入）

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub API令牌
        self.headers = {'Authorization': f'token {self.token}'}  # 设置HTTP头部认证信息

    def fetch_updates(self, repo, since=None, until=None):
        # 获取指定仓库的更新，可以指定开始和结束日期
        updates = {
            'commits': self.fetch_commits(repo, since, until),  # 获取提交记录
            'issues': self.fetch_issues(repo, since, until),  # 获取问题
            'pull_requests': self.fetch_pull_requests(repo, since, until)  # 获取拉取请求
        }
        return updates

    def fetch_commits(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/commits'  # 构建获取提交的API URL
        params = {}
        if since:
            params['since'] = since  # 如果指定了开始日期，添加到参数中
        if until:
            params['until'] = until  # 如果指定了结束日期，添加到参数中

        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()  # 检查请求是否成功
        return response.json()  # 返回JSON格式的数据

    def fetch_issues(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/issues'  # 构建获取问题的API URL
        params = {
            'state': 'closed',  # 仅获取已关闭的问题
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def fetch_pull_requests(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/pulls'  # 构建获取拉取请求的API URL
        params = {
            'state': 'closed',  # 仅获取已合并的拉取请求
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def export_daily_progress(self, repo):
        today = datetime.now().date().isoformat()  # 获取今天的日期
        updates = self.fetch_updates(repo, since=today)  # 获取今天的更新数据
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建存储路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        file_path = os.path.join(repo_dir, f'{today}.md')  # 构建文件路径
        with open(file_path, 'w') as file:
            file.write(f"# Daily Progress for {repo} ({today})\n\n")
            file.write("\n## Issues Closed Today\n")
            for issue in updates['issues']:  # 写入今天关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged Today\n")
            for pr in updates['pull_requests']:  # 写入今天合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported daily progress to {file_path}")  # 记录日志
        return file_path

    def export_progress_by_date_range(self, repo, days):
        today = date.today()  # 获取当前日期
        since = today - timedelta(days=days)  # 计算开始日期
        
        updates = self.fetch_updates(repo, since=since.isoformat(), until=today.isoformat())  # 获取指定日期范围内的更新
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建目录路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        # 更新文件名以包含日期范围
        date_str = f"{since}_to_{today}"
        file_path = os.path.join(repo_dir, f'{date_str}.md')  # 构建文件路径
        
        with open(file_path, 'w') as file:
            file.write(f"# Progress for {repo} ({since} to {today})\n\n")
            file.write(f"\n## Issues Closed in the Last {days} Days\n")
            for issue in updates['issues']:  # 写入在指定日期内关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged in the Last {days} Days\n")
            for pr in updates['pull_requests']:  # 写入在指定日期内合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported time-range progress to {file_path}")  # 记录日志
        return file_path

# %%
# 实例化 v0.3 版本的 GitHub Client
github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### 获取过去1天 LangChain 进展（已关闭的Issues）

# %%
# 获取今天的日期，从午夜开始，ISO 8601格式
today = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取今天关闭的Issues
closed_issues_today = github_client.fetch_issues(repo='langchain-ai/langchain', since=today, until=today)

# 打印今天关闭的Issues标题
for issue in closed_issues_today:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")
# Out:
# Issue #25519: docs: add prompt to install nltk (关闭时间 2024-08-18T06:22:49Z)
# Issue #25518: docs: add prompt to install beautifulsoup4. (关闭时间 2024-08-18T06:23:24Z)

# %%
# 获取过去3天的日期
three_days_ago = datetime.now() - timedelta(days=3)
three_days_ago = three_days_ago.replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取过去3天关闭的Issues
closed_issues_last_3_days = github_client.fetch_issues(repo='langchain-ai/langchain', since=three_days_ago, until=today)

# 打印过去3天关闭的Issues标题
for issue in closed_issues_last_3_days:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")
# Out:
# Issue #25519: docs: add prompt to install nltk (关闭时间 2024-08-18T06:22:49Z)
# Issue #25518: docs: add prompt to install beautifulsoup4. (关闭时间 2024-08-18T06:23:24Z)
# Issue #25508: add embeddings integration tests (关闭时间 2024-08-16T20:20:37Z)
# Issue #25507: "from langchain_anthropic import ChatAnthropic" fails (关闭时间 2024-08-16T20:37:43Z)
# Issue #25504: docs: fix Databricks Vector Search demo notebook (关闭时间 2024-08-16T20:24:30Z)
# Issue #25502: openai[patch]: update core dep (关闭时间 2024-08-16T18:30:18Z)
# Issue #25498: core[patch]: Release 0.2.33 (关闭时间 2024-08-16T18:18:54Z)
# Issue #25496: openai[patch]: Release 0.1.22 (关闭时间 2024-08-16T16:53:04Z)
# Issue #25494: docs: use .invoke rather than __call__ in openai integration notebook (关闭时间 2024-08-16T15:59:18Z)
# Issue #25488: openai[patch]: fix json mode for Azure (关闭时间 2024-08-16T16:50:51Z)
# Issue #25485: langchain_openai>=0.1.21 not compatible with AzureChatOpenAI and response_format={"type": "json_object"} (关闭时间 2024-08-16T13:24:12Z)
# Issue #25482: DOC: <Issue related to /v0.2/docs/tutorials/local_rag/> Missing a requirement (关闭时间 2024-08-18T06:23:25Z)
# Issue #25480: TypeError: Got unknown type 'ToolMessage'. (关闭时间 2024-08-18T00:48:52Z)
# Issue #25479: AzureChatOpenAI's JSON mode fails with AttributeError: 'NoneType' object has no attribute 'beta' (关闭时间 2024-08-16T19:00:12Z)
# Issue #25473: Unstructured Markdown Loader object which requires also NLTK package (关闭时间 2024-08-18T06:22:51Z)
# Issue #25471: The minimum supported Python version for this project (关闭时间 2024-08-16T04:52:56Z)
# Issue #25465: langchain-box: add langchain box package and DocumentLoader (关闭时间 2024-08-16T19:21:08Z)
# Issue #25463: docs: fix mimetype parser docstring (关闭时间 2024-08-15T23:16:53Z)
# Issue #25461: Langchain Agent with Pydantic tools running in Linux Environment  (关闭时间 2024-08-16T02:03:47Z)
# Issue #25458: langchain-box: Add DocumentLoader (关闭时间 2024-08-16T00:53:46Z)
# Issue #25457: core[minor], anthropic[patch]: Upgrade @root_validator usage to be consistent with pydantic 2 (关闭时间 2024-08-15T20:09:35Z)
# Issue #25455: voyageai[patch]: Upgrade root validators for pydantic 2 (关闭时间 2024-08-15T19:30:41Z)
# Issue #25454: ai21[patch]: Upgrade @root_validators for pydantic 2 migration (关闭时间 2024-08-15T18:54:09Z)
# Issue #25453: pinecone[patch]: Upgrade @root_validators to be consistent with pydantic 2 (关闭时间 2024-08-15T19:45:15Z)
# Issue #25450: docs: `arxiv` page update (关闭时间 2024-08-15T18:30:36Z)
# Issue #25448: docs: format oai embeddings docstring (关闭时间 2024-08-15T16:57:55Z)
# Issue #25447: docs: fix api ref mod links in pkg page (关闭时间 2024-08-15T16:52:12Z)
# Issue #25446: mistralai[patch]: Update more @root_validators for pydantic 2 compatibility (关闭时间 2024-08-15T16:44:42Z)
# Issue #25444: docs[patch]: Update code that checks API keys (关闭时间 2024-08-15T16:52:37Z)
# Issue #25443: fireworks[patch]: Upgrade @root_validators to be pydantic 2 compliant  (关闭时间 2024-08-15T16:56:48Z)

# %% [markdown]
# ## 优化导出文件管理
#
# 考虑到 GitHubSentinel 项目长期运行将会生成一大批项目进展文件，因此将所有进展文件统一存储在`daily_progress` 目录下，并按照 `{owners}_{repo}/{since_day}_{until_day}.md` 方式命名。
#
# 如下所示：
#
# ```shell
# daily_progress
# ├── langchain-ai_langchain
# │   ├── 2024-08-04.md
# │   ├── 2024-08-04_report.md
# │   ├── 2024-08-18.md
# │   └── 2024-08-18_report.md
# ├── llm_logs.log
# ├── ollama_ollama
# │   ├── 2024-07-30_to_2024-08-04.md
# │   ├── 2024-07-30_to_2024-08-04_report.md
# │   ├── 2024-08-02_to_2024-08-04.md
# │   ├── 2024-08-02_to_2024-08-04_report.md
# │   ├── 2024-08-04.md
# │   └── 2024-08-04_report.md
# ```

# %%
github_client.export_progress_by_date_range(repo='langchain-ai/langchain', days=3)
# Out:
# 2024-08-18T14:13:15.171549+0000 INFO Exported time-range progress to daily_progress/langchain-ai_langchain/2024-08-15_to_2024-08-18.md
# 'daily_progress/langchain-ai_langchain/2024-08-15_to_2024-08-18.md'

# %%
github_client.export_daily_progress(repo='langchain-ai/langchain')
# Out:
# 2024-08-18T14:13:17.054441+0000 INFO Exported daily progress to daily_progress/langchain-ai_langchain/2024-08-18.md
# 'daily_progress/langchain-ai_langchain/2024-08-18.md'

# %% [markdown]
# ### Homework: [可选] 尝试扩展 GitHubClient，使其支持 Since + Until 参数的特定时间段筛选
# ![image.png](attachment:12c41fc1-1001-4b5c-9905-131457956a2e.png)![image.png](attachment:532f2f6e-17e4-4d49-934e-d7301d9e8d9b.png)![image.png](attachment:d7c01738-e689-409e-b9aa-476cad3f8220.png)![image.png](attachment:bd00a348-af22-4a69-b64d-5f676f9ed7ee.png)
